# %% [markdown]
# 🎯 Fine-tune Wav2Vec2-base on Kurmanci
#
# | Step | Task                                           |
# | ---- | ---------------------------------------------- |
# | 1️⃣  | Preprocess Mozilla `train.tsv` for Kurmanci    |
# | 2️⃣  | Convert to HuggingFace `datasets.Dataset`      |
# | 3️⃣  | Prepare tokenizer (use dummy CTC tokenizer)    |
# | 4️⃣  | Configure Trainer + TrainingArguments          |
# | 5️⃣  | Fine-tune Wav2Vec2-base with CTC loss          |
# | 6️⃣  | Evaluate on `dev.tsv` and compare with Whisper |
#
#
# ✅ Pipeline Summary
# Preload tokenizer & processor
#
# Load + filter train.tsv (1%) & dev.tsv
#
# Preprocess audio and text
#
# Prepare model on GPU (.to("cuda"))
#
# Fine-tune with validation steps
#
# Evaluate WER on test.tsv after training

# %% [markdown]
# Cell 1: Install & Import Dependencies
# This ensures all required Hugging Face and audio tools are ready.

# %%
#✅ Cell 1: Install & Import + Setup Root Paths
import os, re, json, torch
import pandas as pd
import librosa, torchaudio
import numpy as np
from pathlib import Path

from datasets import Dataset, Audio
from transformers import (
    Wav2Vec2ForCTC, Wav2Vec2Processor,
    Wav2Vec2FeatureExtractor, Wav2Vec2CTCTokenizer,
    TrainingArguments, Trainer,
)
from torch.nn.utils.rnn import pad_sequence
import evaluate

jiwer = evaluate.load("wer")

# Setup paths
PROJECT_ROOT = Path(__file__).resolve().parents[1] if "__file__" in globals() else Path.cwd().parents[1]
DATA_DIR = PROJECT_ROOT / "data" / "kurmanci"
MODELS_DIR = PROJECT_ROOT / "models"
OUTPUT_DIR = MODELS_DIR / "wav2vec2-kurmanci-final"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# %%
#✅ Cell 2: Load Kurmanci Dataset (1%)
train_path = "../data/kurmanci/train.tsv"
dev_path = "../data/kurmanci/dev.tsv"
clips_path = "../data/kurmanci/clips"

train_df = pd.read_csv(train_path, sep="\t").dropna(subset=["path", "sentence"])
dev_df = pd.read_csv(dev_path, sep="\t").dropna(subset=["path", "sentence"])
train_df = train_df.sample(frac=0.01, random_state=42)

train_df["path"] = train_df["path"].apply(lambda x: os.path.join(clips_path, x))
dev_df["path"] = dev_df["path"].apply(lambda x: os.path.join(clips_path, x))

train_ds = Dataset.from_pandas(train_df[["path", "sentence"]])
dev_ds = Dataset.from_pandas(dev_df[["path", "sentence"]])

train_ds = train_ds.cast_column("path", Audio(sampling_rate=16000))
dev_ds = dev_ds.cast_column("path", Audio(sampling_rate=16000))

# %%
train_ds["path"]
# Out:
# [{'path': '../data/kurmanci/clips\\common_voice_kmr_35060090.mp3',
#   'array': array([ 1.27329258e-11,  2.91038305e-11,  1.45519152e-11, ...,
#           3.83282409e-20, -2.89579389e-20,  2.30187821e-20], shape=(43200,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_35064883.mp3',
#   'array': array([-7.27595761e-11,  1.45519152e-11,  1.45519152e-10, ...,
#           5.04088291e-07, -1.02555339e-06, -6.17599312e-07], shape=(46656,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_35249487.mp3',
#   'array': array([ 2.18278728e-11,  1.09139364e-11, -1.09139364e-11, ...,
#           2.05973083e-06,  1.18813768e-05, -1.21401281e-05], shape=(35136,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_25313893.mp3',
#   'array': array([3.63797881e-12, 1.81898940e-12, 1.09139364e-11, ...,
#          1.41435885e-06, 4.42025339e-06, 1.39267922e-06], shape=(79488,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_34912457.mp3',
#   'array': array([ 4.00177669e-11,  2.54658516e-11, -3.63797881e-12, ...,
#           1.25726535e-06,  7.34184027e-07,  9.69074790e-07], shape=(51840,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_34782183.mp3',
#   'array': array([-1.11022302e-15, -7.77156117e-16,  1.33226763e-15, ...,
#          -1.16398049e-07,  2.38247146e-08,  9.25860135e-08], shape=(39168,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_25000937.mp3',
#   'array': array([-3.86535248e-12, -3.46744855e-12, -2.27373675e-13, ...,
#          -3.40502595e-07,  8.11805201e-09,  2.47173944e-07], shape=(37440,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_34782686.mp3',
#   'array': array([-6.66133815e-16,  6.66133815e-16,  2.22044605e-16, ...,
#           5.33962066e-07, -1.72839509e-06, -3.24499752e-06], shape=(42624,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_35116554.mp3',
#   'array': array([-2.54658516e-11,  0.00000000e+00, -1.45519152e-11, ...,
#          -1.03434750e-05, -8.54507016e-06,  5.20906156e-07], shape=(31680,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_25112290.mp3',
#   'array': array([-3.49245965e-10, -9.31322575e-10,  3.49245965e-10, ...,
#          -1.09306711e-07,  9.52422852e-08,  2.83074769e-07], shape=(66240,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_35064905.mp3',
#   'array': array([2.27373675e-12, 1.93267624e-12, 2.16004992e-12, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00], shape=(52416,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_24888208.mp3',
#   'array': array([ 1.36424205e-11,  7.27595761e-12,  0.00000000e+00, ...,
#           7.67605115e-07, -7.16176601e-07, -1.64453013e-06], shape=(55296,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_34815773.mp3',
#   'array': array([ 1.36424205e-12, -9.09494702e-13, -9.09494702e-13, ...,
#           4.61749266e-07, -5.65199002e-07, -1.23065803e-07], shape=(46656,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_24856274.mp3',
#   'array': array([1.50990331e-14, 8.43769499e-15, 5.32907052e-15, ...,
#          5.47773379e-06, 2.95745849e-06, 4.84620250e-06], shape=(55296,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_34827046.mp3',
#   'array': array([ 2.22044605e-16, -1.94289029e-15,  2.16493490e-15, ...,
#          -1.37345523e-07, -5.08825906e-08, -4.70581654e-08], shape=(95616,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_36962911.mp3',
#   'array': array([ 5.82076609e-11,  5.09317033e-11,  6.18456397e-11, ...,
#           4.00204044e-07,  2.74835384e-06, -2.68165877e-07], shape=(89856,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_25013562.mp3',
#   'array': array([ 2.91038305e-11,  1.74622983e-10, -5.82076609e-11, ...,
#          -1.40629243e-04,  9.02127940e-05, -1.15709845e-04], shape=(82944,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_24840561.mp3',
#   'array': array([0., 0., 0., ..., 0., 0., 0.], shape=(80640,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_36976665.mp3',
#   'array': array([ 1.36424205e-11, -1.81898940e-12, -5.45696821e-12, ...,
#           7.47717422e-07,  5.82109351e-07,  1.20430741e-06], shape=(55296,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_35058693.mp3',
#   'array': array([0., 0., 0., ..., 0., 0., 0.], shape=(40320,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_34941128.mp3',
#   'array': array([ 5.32907052e-14,  6.39488462e-14,  5.15143483e-14, ...,
#          -4.39304040e-06, -2.82780320e-06, -1.49359039e-06], shape=(58176,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_24965730.mp3',
#   'array': array([-9.09494702e-13,  1.45519152e-11,  1.00044417e-11, ...,
#           1.77606125e-08, -4.63291883e-07, -1.73331500e-07], shape=(89280,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_34973694.mp3',
#   'array': array([-9.09494702e-13, -1.08002496e-12, -2.84217094e-14, ...,
#          -6.30266399e-08,  1.30095941e-07,  8.99110404e-08], shape=(50688,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_34911646.mp3',
#   'array': array([0., 0., 0., ..., 0., 0., 0.], shape=(72000,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_34817207.mp3',
#   'array': array([-1.77635684e-15,  2.44249065e-15, -1.77635684e-15, ...,
#          -6.36646291e-12,  4.88853402e-12,  5.00222086e-12], shape=(51264,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_36513070.mp3',
#   'array': array([ 3.12638804e-12, -1.81898940e-12,  8.18545232e-12, ...,
#          -2.48963006e-05, -1.53991095e-05,  1.28062311e-06], shape=(42624,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_35132097.mp3',
#   'array': array([-2.18278728e-11, -7.27595761e-12,  1.45519152e-11, ...,
#           1.84563305e-06,  3.08740846e-06,  2.11510087e-06], shape=(86400,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_35070601.mp3',
#   'array': array([-8.73114914e-11,  8.00355338e-11,  0.00000000e+00, ...,
#           3.03771230e-09,  3.07773007e-09,  5.14046405e-09], shape=(49536,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_35095350.mp3',
#   'array': array([ 2.91038305e-11, -3.27418093e-11,  7.27595761e-12, ...,
#           1.10035207e-05,  1.04888329e-06, -1.96494875e-06], shape=(35712,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_35063953.mp3',
#   'array': array([ 2.00088834e-11,  5.45696821e-12,  2.72848411e-12, ...,
#          -1.35784358e-05, -2.13307940e-05,  1.23120844e-06], shape=(46080,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_34935421.mp3',
#   'array': array([-1.01863407e-10,  5.82076609e-11,  6.54836185e-11, ...,
#           1.48997981e-06, -8.73379122e-07, -1.79494259e-06], shape=(39168,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_25086674.mp3',
#   'array': array([-2.32830644e-10, -8.73114914e-11, -8.00355338e-11, ...,
#          -2.91038305e-09,  1.07102096e-08,  3.43425199e-09], shape=(62208,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_34815775.mp3',
#   'array': array([-3.63797881e-11, -4.00177669e-11, -4.36557457e-11, ...,
#           4.13938579e-07, -8.84120766e-07,  3.18289040e-09], shape=(43776,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_24964650.mp3',
#   'array': array([-1.81898940e-12,  3.63797881e-11, -3.27418093e-11, ...,
#          -2.45144474e-06, -1.92038715e-06, -9.84757207e-07], shape=(60480,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_34817895.mp3',
#   'array': array([ 1.66533454e-15, -1.66533454e-15, -1.11022302e-16, ...,
#          -1.06865627e-11, -9.09494702e-13, -5.91171556e-12], shape=(54720,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_35341252.mp3',
#   'array': array([-1.09139364e-11,  1.52795110e-10,  1.30967237e-10, ...,
#           5.54269645e-05,  9.20158345e-05,  1.21346908e-04], shape=(43776,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_34845471.mp3',
#   'array': array([ 7.85803422e-10,  3.49245965e-10,  9.31322575e-10, ...,
#          -4.01652869e-07,  5.31617843e-08,  1.26610757e-07], shape=(48960,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_34940775.mp3',
#   'array': array([0., 0., 0., ..., 0., 0., 0.], shape=(46656,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_24986163.mp3',
#   'array': array([ 1.36424205e-12,  2.72848411e-12,  2.72848411e-12, ...,
#          -4.23875827e-06, -5.20888352e-06,  1.02463055e-05], shape=(128448,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_24845729.mp3',
#   'array': array([0., 0., 0., ..., 0., 0., 0.], shape=(77760,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_35082380.mp3',
#   'array': array([ 5.00222086e-12,  5.68434189e-13,  2.04636308e-12, ...,
#          -2.28412134e-08, -2.64158473e-09, -2.99338865e-08], shape=(51840,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_35080300.mp3',
#   'array': array([ 3.63797881e-11,  6.36646291e-12,  0.00000000e+00, ...,
#          -1.29832733e-06, -6.54168161e-07,  1.82277654e-06], shape=(70272,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_24853263.mp3',
#   'array': array([ 6.82121026e-12, -5.45696821e-12,  1.09139364e-11, ...,
#          -4.03037120e-06, -3.36167432e-06, -8.23595838e-06], shape=(111168,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_24877195.mp3',
#   'array': array([-4.54747351e-13, -1.59161573e-12, -2.27373675e-13, ...,
#          -2.25627446e-06,  6.21203799e-06,  1.06008083e-05], shape=(65088,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_26201672.mp3',
#   'array': array([ 9.09494702e-12,  5.45696821e-12, -7.27595761e-12, ...,
#           6.12748636e-07,  8.77482549e-08,  3.62345958e-08], shape=(39168,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_36976755.mp3',
#   'array': array([-2.27373675e-12, -5.91171556e-12, -8.18545232e-12, ...,
#          -1.15097191e-06,  5.09044185e-07,  8.29753844e-07], shape=(72000,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_34818642.mp3',
#   'array': array([-3.63797881e-12,  1.45519152e-11,  9.09494702e-12, ...,
#          -2.86797513e-06,  1.55764428e-06,  2.23117240e-06], shape=(49536,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_34819403.mp3',
#   'array': array([-2.91038305e-11, -1.45519152e-11,  1.45519152e-11, ...,
#           5.59876935e-06,  3.17364902e-05,  3.75439413e-06], shape=(35136,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_25367134.mp3',
#   'array': array([0., 0., 0., ..., 0., 0., 0.], shape=(48960,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_36537040.mp3',
#   'array': array([ 3.27418093e-11,  1.09139364e-10,  1.27329258e-11, ...,
#          -2.38307348e-06, -7.98835572e-07,  7.37595929e-06], shape=(78336,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_36481275.mp3',
#   'array': array([-7.27595761e-12,  1.01863407e-10,  1.01863407e-10, ...,
#           3.34706920e-06, -1.90243099e-07, -2.91813819e-07], shape=(86400,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_35063979.mp3',
#   'array': array([-2.91038305e-11,  1.23691279e-10,  5.09317033e-11, ...,
#           1.55896887e-05, -4.06539766e-06,  2.25265612e-05], shape=(36288,)),
#   'sampling_rate': 16000},
#  {'path': '../data/kurmanci/clips\\common_voice_kmr_24950106.mp3',
#   'array': array([ 3.63797881e-12,  5.45696821e-12, -2.72848411e-12, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00], shape=(95616,)),
#   'sampling_rate': 16000}]

# %%
#✅ Cell 3: Build Character-Level Tokenizer and feature extractor
vocab_set = set()
for s in train_df["sentence"]:
    vocab_set.update(list(s.lower()))

vocab_list = sorted(list(vocab_set - {" "}))
vocab_dict = {v: k for k, v in enumerate(vocab_list)}
vocab_dict["|"] = len(vocab_dict)
vocab_dict["[UNK]"] = len(vocab_dict)
vocab_dict["[PAD]"] = len(vocab_dict)

vocab_path = PROJECT_ROOT / "kurmanci_vocab.json"
with vocab_path.open("w", encoding="utf-8") as f:
    json.dump(vocab_dict, f)

tokenizer = Wav2Vec2CTCTokenizer(
    str(vocab_path), unk_token="[UNK]", pad_token="[PAD]", word_delimiter_token="|"
)

feature_extractor = Wav2Vec2FeatureExtractor(
    feature_size=1, sampling_rate=16000,
    padding_value=0.0, do_normalize=True,
    return_attention_mask=True
)

processor = Wav2Vec2Processor(feature_extractor=feature_extractor, tokenizer=tokenizer)

processor
# Out:
# Wav2Vec2Processor:
# - feature_extractor: Wav2Vec2FeatureExtractor {
#   "do_normalize": true,
#   "feature_extractor_type": "Wav2Vec2FeatureExtractor",
#   "feature_size": 1,
#   "padding_side": "right",
#   "padding_value": 0.0,
#   "return_attention_mask": true,
#   "sampling_rate": 16000
# }
#
# - tokenizer: Wav2Vec2CTCTokenizer(name_or_path='', vocab_size=40, model_max_length=1000000000000000019884624838656, is_fast=False, padding_side='right', truncation_side='right', special_tokens={'bos_token': '<s>', 'eos_token': '</s>', 'unk_token': '[UNK]', 'pad_token': '[PAD]'}, clean_up_tokenization_spaces=False, added_tokens_decoder={
# 	38: AddedToken("[UNK]", rstrip=True, lstrip=True, single_word=False, normalized=False, special=False),
# 	39: AddedToken("[PAD]", rstrip=True, lstrip=True, single_word=False, normalized=False, special=False),
# 	40: AddedToken("<s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	41: AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }
# )
#
# {
#   "processor_class": "Wav2Vec2Processor"
# }

# %% [markdown]
# Cell 4: Preprocess the dataset (audio → input + label)

# %%
#✅ Cell 4: Preprocess Audio/Text
def preprocess(batch):
    audio = batch["path"]
    inputs = processor(audio["array"], sampling_rate=16000, return_attention_mask=True)
    with processor.as_target_processor():
        labels = processor(batch["sentence"]).input_ids
    return {
        "input_values": inputs.input_values[0],
        "attention_mask": inputs.attention_mask[0],
        "labels": labels,
    }

train_ds = train_ds.map(preprocess, remove_columns=train_ds.column_names)
dev_ds = dev_ds.map(preprocess, remove_columns=dev_ds.column_names)
# Out:
# Map:   0%|          | 0/53 [00:00<?, ? examples/s]c:\Users\berfi\anaconda3\envs\dialect_env\lib\site-packages\transformers\models\wav2vec2\processing_wav2vec2.py:174: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# Map: 100%|██████████| 53/53 [00:00<00:00, 352.79 examples/s]
# Map: 100%|██████████| 3973/3973 [00:14<00:00, 265.64 examples/s]

# %%
(train_ds["labels"])
# Out:
# [[38, 31, 37, 19, 10, 7, 33, 13, 19, 14, 15, 34, 18, 4],
#  [38, 28, 37, 7, 14, 17, 14, 19, 9, 37, 19, 10, 7, 35, 30, 10, 4],
#  [38, 27, 37, 8, 34, 37, 27, 6, 17, 6, 37, 30, 10, 5],
#  [38,
#   14,
#   37,
#   24,
#   10,
#   23,
#   37,
#   28,
#   6,
#   19,
#   37,
#   29,
#   10,
#   7,
#   6,
#   25,
#   10,
#   16,
#   10,
#   37,
#   31,
#   6,
#   19,
#   14,
#   24,
#   25,
#   34,
#   37,
#   19,
#   10,
#   13,
#   6,
#   25,
#   14,
#   30,
#   10,
#   37,
#   16,
#   14,
#   23,
#   14,
#   19,
#   4],
#  [38, 6, 23, 33, 37, 25, 10, 37, 32, 14, 37, 30, 10, 5],
#  [38, 14, 23, 10, 27, 10, 4],
#  [38, 28, 37, 16, 6, 23, 37, 9, 14, 16, 14, 19],
#  [38, 20, 18, 37, 9, 14, 37, 9, 10, 23, 24, 33, 37, 9, 10, 37, 7, 35, 5],
#  [38, 6, 19, 37, 7, 14, 15, 6, 23, 25, 4],
#  [38,
#   10,
#   23,
#   37,
#   9,
#   20,
#   23,
#   2,
#   37,
#   8,
#   34,
#   23,
#   6,
#   19,
#   37,
#   35,
#   37,
#   12,
#   26,
#   19,
#   9,
#   34,
#   37,
#   25,
#   33,
#   19,
#   37,
#   13,
#   10,
#   28,
#   6,
#   23,
#   6,
#   37,
#   28,
#   6,
#   19],
#  [38, 28, 37, 33, 37, 7, 14, 7, 10, 23, 24, 14, 27, 34, 19, 10, 4],
#  [38, 33, 11, 6, 37, 18, 10, 37, 21, 14, 23, 37, 9, 14, 13, 6, 25],
#  [38, 10, 25, 14, 23, 24, 10, 0],
#  [38, 35, 19, 37, 9, 14, 16, 6, 23, 14, 19, 37, 7, 14, 7, 34, 19, 14, 19],
#  [38,
#   31,
#   37,
#   33,
#   37,
#   15,
#   14,
#   37,
#   38,
#   6,
#   23,
#   30,
#   33,
#   37,
#   23,
#   10,
#   37,
#   12,
#   26,
#   24,
#   25,
#   34,
#   17,
#   16,
#   10,
#   16,
#   10,
#   37,
#   10,
#   17,
#   18,
#   6,
#   24,
#   34,
#   37,
#   7,
#   14,
#   16,
#   14,
#   23,
#   14,
#   18,
#   4],
#  [38,
#   14,
#   37,
#   38,
#   35,
#   36,
#   33,
#   37,
#   9,
#   14,
#   7,
#   14,
#   24,
#   25,
#   6,
#   19,
#   10,
#   16,
#   33,
#   37,
#   34,
#   24,
#   6,
#   17,
#   37,
#   9,
#   26,
#   37,
#   18,
#   14,
#   17,
#   30,
#   20,
#   19,
#   37,
#   17,
#   34,
#   23,
#   10,
#   37,
#   9,
#   6,
#   13,
#   6,
#   25,
#   37,
#   7,
#   14,
#   37,
#   9,
#   10,
#   24,
#   25,
#   37,
#   29,
#   14,
#   24,
#   25,
#   4],
#  [38,
#   20,
#   18,
#   10,
#   17,
#   10,
#   30,
#   6,
#   37,
#   38,
#   6,
#   23,
#   24,
#   6,
#   31,
#   33,
#   19,
#   37,
#   38,
#   26,
#   23,
#   9,
#   3,
#   38,
#   14,
#   23,
#   16,
#   37,
#   13,
#   6,
#   25,
#   10,
#   37,
#   6,
#   27,
#   6,
#   16,
#   14,
#   23,
#   14,
#   19],
#  [38,
#   10,
#   18,
#   6,
#   37,
#   18,
#   14,
#   19,
#   37,
#   13,
#   10,
#   27,
#   6,
#   17,
#   33,
#   19,
#   37,
#   29,
#   28,
#   10,
#   37,
#   9,
#   14,
#   37,
#   7,
#   6,
#   29,
#   32,
#   10,
#   30,
#   33,
#   37,
#   9,
#   14,
#   7,
#   14,
#   24,
#   25,
#   6,
#   19,
#   33,
#   37,
#   9,
#   10,
#   37,
#   9,
#   34,
#   25,
#   14,
#   19,
#   4],
#  [38,
#   34,
#   23,
#   20,
#   16,
#   10,
#   16,
#   10,
#   37,
#   31,
#   14,
#   19,
#   9,
#   34,
#   37,
#   17,
#   14,
#   37,
#   21,
#   6,
#   30,
#   25,
#   10,
#   29,
#   25,
#   33,
#   37,
#   17,
#   14,
#   37,
#   38,
#   10,
#   17,
#   10,
#   13,
#   6,
#   37,
#   38,
#   10,
#   28,
#   17,
#   33,
#   23,
#   33,
#   4],
#  [38, 31, 37, 19, 10, 7, 10, 31, 14, 30, 6, 18, 4],
#  [38,
#   21,
#   33,
#   19,
#   37,
#   28,
#   6,
#   19,
#   37,
#   15,
#   14,
#   37,
#   16,
#   26,
#   37,
#   19,
#   10,
#   5,
#   37,
#   1,
#   38,
#   20,
#   23,
#   28,
#   33,
#   8,
#   4,
#   1],
#  [30,
#   33,
#   19,
#   37,
#   17,
#   14,
#   37,
#   12,
#   26,
#   19,
#   9,
#   37,
#   15,
#   14,
#   30,
#   6,
#   19,
#   10,
#   37,
#   32,
#   6,
#   19,
#   9,
#   6,
#   37,
#   12,
#   26,
#   19,
#   9,
#   37,
#   9,
#   14,
#   31,
#   6,
#   19,
#   14,
#   19],
#  [38,
#   6,
#   27,
#   33,
#   37,
#   28,
#   34,
#   37,
#   30,
#   33,
#   37,
#   23,
#   6,
#   24,
#   25,
#   34,
#   19,
#   37,
#   7,
#   14,
#   37,
#   16,
#   6,
#   23,
#   37,
#   19,
#   34,
#   19,
#   10,
#   4],
#  [38,
#   28,
#   10,
#   19,
#   9,
#   10,
#   16,
#   6,
#   23,
#   33,
#   19,
#   37,
#   9,
#   14,
#   19,
#   37,
#   32,
#   6,
#   28,
#   6,
#   37,
#   6,
#   17,
#   34,
#   16,
#   6,
#   23,
#   14,
#   30,
#   6,
#   37,
#   28,
#   34,
#   37,
#   16,
#   14,
#   23,
#   14,
#   19,
#   5],
#  [38,
#   14,
#   19,
#   37,
#   22,
#   10,
#   25,
#   37,
#   25,
#   14,
#   36,
#   25,
#   10,
#   16,
#   34,
#   37,
#   28,
#   14,
#   13,
#   6,
#   37,
#   19,
#   10,
#   9,
#   34,
#   25,
#   14,
#   7,
#   35,
#   4],
#  [38,
#   26,
#   37,
#   15,
#   14,
#   37,
#   6,
#   27,
#   15,
#   10,
#   19,
#   14,
#   30,
#   33,
#   37,
#   13,
#   10,
#   31,
#   37,
#   9,
#   14,
#   16,
#   34,
#   5],
#  [38,
#   14,
#   37,
#   19,
#   6,
#   27,
#   10,
#   23,
#   20,
#   16,
#   6,
#   37,
#   32,
#   34,
#   23,
#   20,
#   16,
#   33,
#   37,
#   9,
#   10,
#   37,
#   23,
#   10,
#   28,
#   36,
#   33,
#   19,
#   37,
#   29,
#   10,
#   18,
#   12,
#   34,
#   19,
#   14,
#   30,
#   33,
#   37,
#   9,
#   10,
#   23,
#   7,
#   6,
#   24,
#   37,
#   9,
#   14,
#   7,
#   14,
#   19,
#   4],
#  [38, 28, 37, 33, 37, 7, 14, 7, 14, 13, 34, 31, 14, 19, 4],
#  [38,
#   35,
#   19,
#   37,
#   17,
#   14,
#   37,
#   7,
#   10,
#   23,
#   37,
#   29,
#   28,
#   10,
#   37,
#   9,
#   14,
#   16,
#   10,
#   27,
#   14,
#   19,
#   4],
#  [38,
#   10,
#   37,
#   7,
#   33,
#   23,
#   14,
#   30,
#   6,
#   37,
#   18,
#   6,
#   17,
#   33,
#   37,
#   19,
#   10,
#   16,
#   14,
#   23,
#   14,
#   30,
#   10,
#   4],
#  [38,
#   14,
#   30,
#   6,
#   18,
#   10,
#   25,
#   10,
#   16,
#   37,
#   13,
#   10,
#   27,
#   6,
#   17,
#   33,
#   19,
#   37,
#   18,
#   14,
#   19,
#   37,
#   13,
#   10,
#   19,
#   10,
#   4],
#  [32,
#   6,
#   19,
#   9,
#   6,
#   37,
#   19,
#   10,
#   9,
#   14,
#   12,
#   34,
#   13,
#   34,
#   36,
#   25,
#   37,
#   27,
#   33,
#   37,
#   6,
#   24,
#   25,
#   33,
#   4],
#  [38, 14, 19, 37, 9, 34, 25, 0],
#  [38,
#   6,
#   30,
#   37,
#   35,
#   37,
#   7,
#   6,
#   17,
#   6,
#   37,
#   18,
#   14,
#   19,
#   37,
#   15,
#   14,
#   37,
#   13,
#   10,
#   23,
#   37,
#   9,
#   10,
#   23,
#   33,
#   37,
#   13,
#   10,
#   30,
#   10],
#  [38, 31, 37, 29, 28, 10, 19, 9, 10, 16, 6, 23, 10, 16, 37, 14, 18, 4],
#  [38, 33, 37, 19, 10, 6, 23, 6, 24, 25, 14, 30, 10, 4],
#  [38,
#   14,
#   19,
#   37,
#   16,
#   20,
#   18,
#   7,
#   10,
#   23,
#   24,
#   10,
#   16,
#   10,
#   37,
#   19,
#   35,
#   37,
#   13,
#   10,
#   30,
#   10,
#   4],
#  [38, 6, 19, 37, 7, 34, 19, 14, 19, 37, 13, 26, 19, 9, 14, 23, 4],
#  [38,
#   35,
#   25,
#   16,
#   10,
#   37,
#   35,
#   37,
#   18,
#   6,
#   28,
#   10,
#   30,
#   6,
#   37,
#   9,
#   6,
#   28,
#   34,
#   37,
#   30,
#   6,
#   37,
#   36,
#   10,
#   28,
#   7,
#   10,
#   30,
#   33,
#   37,
#   19,
#   10,
#   9,
#   14,
#   30,
#   6,
#   23,
#   37,
#   10,
#   37,
#   35,
#   37,
#   17,
#   14,
#   37,
#   12,
#   20,
#   23,
#   37,
#   8,
#   14,
#   13,
#   37,
#   9,
#   14,
#   16,
#   6,
#   23,
#   10,
#   37,
#   7,
#   14,
#   12,
#   26,
#   13,
#   10,
#   23,
#   10,
#   4],
#  [38,
#   28,
#   10,
#   9,
#   34,
#   37,
#   9,
#   10,
#   23,
#   16,
#   10,
#   25,
#   14,
#   19,
#   6,
#   37,
#   31,
#   14,
#   18,
#   6,
#   19,
#   37,
#   33,
#   9,
#   34,
#   37,
#   9,
#   14,
#   37,
#   9,
#   10,
#   24,
#   25,
#   33,
#   37,
#   18,
#   10,
#   37,
#   9,
#   10,
#   37,
#   30,
#   10,
#   4],
#  [38, 28, 37, 9, 14, 7, 33, 13, 19, 14, 15, 10, 4],
#  [38,
#   14,
#   37,
#   27,
#   6,
#   19,
#   37,
#   24,
#   6,
#   17,
#   33,
#   19,
#   37,
#   9,
#   6,
#   28,
#   34,
#   37,
#   9,
#   10,
#   37,
#   24,
#   34,
#   19,
#   10,
#   18,
#   6,
#   30,
#   6,
#   37,
#   38,
#   14,
#   19,
#   9,
#   14,
#   24,
#   25,
#   6,
#   19,
#   33,
#   37,
#   21,
#   14,
#   23,
#   37,
#   7,
#   14,
#   37,
#   21,
#   33,
#   36,
#   37,
#   16,
#   10,
#   25,
#   4],
#  [38,
#   14,
#   18,
#   37,
#   23,
#   20,
#   37,
#   9,
#   10,
#   23,
#   16,
#   10,
#   25,
#   14,
#   30,
#   10,
#   2,
#   37,
#   13,
#   14,
#   18,
#   37,
#   21,
#   10,
#   36,
#   16,
#   33,
#   37,
#   7,
#   6,
#   23,
#   6,
#   19,
#   33,
#   37,
#   25,
#   33,
#   37,
#   35,
#   37,
#   13,
#   14,
#   18,
#   37,
#   7,
#   10,
#   23,
#   11,
#   37,
#   9,
#   14,
#   7,
#   6,
#   23,
#   10,
#   4],
#  [38,
#   26,
#   37,
#   30,
#   33,
#   37,
#   7,
#   14,
#   37,
#   8,
#   34,
#   23,
#   6,
#   19,
#   37,
#   23,
#   10,
#   37,
#   7,
#   14,
#   37,
#   22,
#   14,
#   23,
#   25,
#   14,
#   22,
#   37,
#   7,
#   34,
#   4],
#  [38, 14, 19, 37, 6, 27, 33, 37, 27, 10, 9, 14, 29, 28, 10, 4],
#  [38,
#   14,
#   17,
#   37,
#   38,
#   14,
#   11,
#   10,
#   25,
#   37,
#   9,
#   14,
#   37,
#   28,
#   6,
#   23,
#   33,
#   19,
#   37,
#   24,
#   10,
#   23,
#   7,
#   6,
#   31,
#   34,
#   37,
#   35,
#   37,
#   34,
#   9,
#   6,
#   23,
#   34,
#   37,
#   9,
#   14,
#   37,
#   9,
#   10,
#   24,
#   25,
#   33,
#   37,
#   13,
#   14,
#   16,
#   35,
#   18,
#   10,
#   25,
#   33,
#   37,
#   9,
#   10,
#   37,
#   30,
#   10,
#   4],
#  [38, 27, 37, 21, 14, 24, 34, 16, 10, 16, 6, 37, 24, 21, 34, 37, 30, 10, 4],
#  [38,
#   10,
#   15,
#   19,
#   6,
#   37,
#   7,
#   6,
#   27,
#   33,
#   37,
#   25,
#   10,
#   37,
#   9,
#   14,
#   23,
#   33,
#   15,
#   37,
#   10,
#   4],
#  [38, 31, 37, 9, 14, 29, 28, 6, 31, 14, 18, 37, 27, 10, 22, 10, 25, 14, 18, 4],
#  [38,
#   26,
#   37,
#   21,
#   20,
#   23,
#   33,
#   19,
#   37,
#   28,
#   6,
#   19,
#   37,
#   15,
#   34,
#   37,
#   28,
#   10,
#   36,
#   14,
#   30,
#   6,
#   37,
#   7,
#   14,
#   19,
#   37,
#   15,
#   14,
#   37,
#   7,
#   14,
#   19,
#   34,
#   37,
#   27,
#   10,
#   37,
#   7,
#   33,
#   29,
#   33,
#   23,
#   37,
#   9,
#   14,
#   7,
#   14,
#   19,
#   4],
#  [38,
#   14,
#   37,
#   7,
#   20,
#   37,
#   8,
#   34,
#   13,
#   6,
#   19,
#   10,
#   16,
#   10,
#   37,
#   7,
#   6,
#   36,
#   25,
#   14,
#   23,
#   37,
#   9,
#   14,
#   27,
#   33,
#   37,
#   13,
#   10,
#   18,
#   35,
#   37,
#   19,
#   10,
#   25,
#   10,
#   28,
#   10,
#   37,
#   7,
#   33,
#   19,
#   37,
#   21,
#   6,
#   23,
#   6,
#   24,
#   25,
#   14,
#   19,
#   4],
#  [38, 33, 37, 7, 14, 37, 9, 10, 24, 25, 37, 29, 14, 24, 25, 4],
#  [38,
#   14,
#   13,
#   10,
#   18,
#   10,
#   9,
#   37,
#   7,
#   14,
#   37,
#   7,
#   14,
#   32,
#   35,
#   16,
#   6,
#   25,
#   14,
#   30,
#   6,
#   37,
#   29,
#   28,
#   10,
#   37,
#   23,
#   10,
#   37,
#   17,
#   14,
#   37,
#   8,
#   14,
#   27,
#   6,
#   25,
#   6,
#   19,
#   37,
#   9,
#   14,
#   7,
#   10,
#   37,
#   29,
#   28,
#   10,
#   9,
#   34,
#   37,
#   19,
#   6,
#   27,
#   4]]

# %%
train_ds
# Out:
# Dataset({
#     features: ['input_values', 'attention_mask', 'labels'],
#     num_rows: 53
# })

# %%
#✅ Cell 5: Dynamic Padding Collator
class CustomCTCCollator:
    def __init__(self, processor):
        self.processor = processor
        self.pad_token_id = processor.tokenizer.pad_token_id

    def __call__(self, batch):
        input_values = [torch.tensor(b["input_values"]) for b in batch]
        attention_mask = [torch.tensor(b["attention_mask"]) for b in batch]
        labels = [torch.tensor(b["labels"]) for b in batch]

        return {
            "input_values": pad_sequence(input_values, batch_first=True, padding_value=0.0),
            "attention_mask": pad_sequence(attention_mask, batch_first=True, padding_value=0),
            "labels": pad_sequence(labels, batch_first=True, padding_value=self.pad_token_id),
        }

data_collator = CustomCTCCollator(processor)

# %% [markdown]
# Cell 6 – TrainingArguments

# %%
#✅ Cell 6: Load Pretrained Wav2Vec2 Base
model = Wav2Vec2ForCTC.from_pretrained(
    "facebook/wav2vec2-large-xlsr-53",
    vocab_size=len(processor.tokenizer),
    cache_dir=MODELS_DIR / "wav2vec2-base"
).to("cuda")
# Out:
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-large-xlsr-53 and are newly initialized: ['lm_head.bias', 'lm_head.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# Cell 7 – Trainer Setup

# %%
#✅ Cell 7: Trainer Configuration
training_args = TrainingArguments(
    output_dir=str(OUTPUT_DIR),
    group_by_length=True,
    per_device_train_batch_size=2,
    gradient_accumulation_steps=2,
    evaluation_strategy="epoch",
    num_train_epochs=2,
    fp16=True,
    save_steps=500,
    save_total_limit=1,
    logging_steps=25,
    learning_rate=6e-5,
    warmup_steps=50,
    weight_decay=0.005,
    report_to="none",
    push_to_hub=False
)

# %%
train_ds
# Out:
# Dataset({
#     features: ['input_values', 'attention_mask', 'labels'],
#     num_rows: 53
# })

# %%
#✅ Cell 8: Metrics & Trainer Setup
wer_metric = evaluate.load("wer")

def compute_metrics(pred):
    pred_logits = pred.predictions
    pred_ids = np.argmax(pred_logits, axis=-1)

    pred_str = processor.batch_decode(pred_ids)
    label_ids = pred.label_ids
    label_ids[label_ids == -100] = processor.tokenizer.pad_token_id
    label_str = processor.batch_decode(label_ids, group_tokens=False)

    wer = wer_metric.compute(predictions=pred_str, references=label_str)
    return {"wer": wer}

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_ds,
    eval_dataset=dev_ds,
    tokenizer=processor.feature_extractor,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)
# Out:
# C:\Users\berfi\AppData\Local\Temp\ipykernel_11600\999635025.py:34: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %% [markdown]
# Cell 9: Start training

# %%
trainer.train()
print("🎉 Training complete!")

metrics = trainer.evaluate()
print("✅ Evaluation metrics:", metrics)

trainer.save_model("./wav2vec2-kurmanci-final")
processor.save_pretrained("./wav2vec2-kurmanci-final")
# Out:
#     <div>
#
#       <progress value='26' max='26' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [26/26 1:20:33, Epoch 1/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1113.542300</td>
#       <td>5068.975586</td>
#       <td>1.000804</td>
#     </tr>
#   </tbody>
# </table><p>
# 🎉 Training complete!
#     <div>
#
#       <progress value='497' max='497' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [497/497 36:34]
#     </div>
# ✅ Evaluation metrics: {'eval_loss': 5070.03662109375, 'eval_wer': 1.0010153572788425, 'eval_runtime': 2207.1141, 'eval_samples_per_second': 1.8, 'eval_steps_per_second': 0.225, 'epoch': 1.8888888888888888}
# []
